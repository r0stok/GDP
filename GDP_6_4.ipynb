# %% [markdown]
# <div style="display:block; margin-bottom:50px">
# <h1 style="margin-bottom:25px; font-size:3.5rem;color:#4c76ce;text-align:center;">
#     Gross Domestic Product</h1>
#
# <h2 style="margin-bottom: 25px;font-size:2.5rem;text-align:center; color:orangered;">
#     Let's Visualize It!</h2>
#
# <img src="https://github.com/lajm-programming/data-analysis-2023/raw/main/Images/gdp.jpg"
#      style="position:absolute;top:5px;left:25px;height:150px;width:auto;margin-bottom:35px;">
# </div>

# %% [markdown]
# # Gross Domestic Product (GDP)

# %% [markdown]
# **GDP** is the total monetary market value of all the finished goods and services produced within the country borders in a specific time period. GDP acts as a comprehensive scorecard of a country's economic health, and it is a key tool for investors, and business decision makers.
#
# GDP enables policymakers and central banks to judge whether the economy is contracting or expanding, whether it needs a boost or restraint, and if a threat such as a recession or inflation looms on the horizon.

# %% [markdown]
# ## 1. Nominal GDP and Real GDP
#
# GDP can be adjusted for inflation to provide deeper insights. **Real GDP** takes into account the effects of inflation while **Nominal GDP** does not. Real GDP is a better method for expressing long-term national economics performance.
#
# **Nominal GDP** is an assessment of economic production in current prices. All goods and services counted in nominal GDP are valued at the prices that those goods and services are actually sold in that year.
#
# **Real GDP** is an inflation-adjusted measure that reflects the number of goods and services produced by an economy in a given year, with prices held constant from year to year to separate out the impact of inflation or deflation from the trend in output over time. Since GDP is based on the monetary value of goods and services, it is subject to inflation.

# %% [markdown]
# ## Exercise 1: Nominal GDP and Real GDP
#
# Let's say a country had a nominal GDP of 100 billion EUR in 2012. By 2022 its nominal GDP grew to 150 billion EUR, but prices rose 100 %.
#
# Let's assume that GDP growth was 5 billion EUR a year, and let's say, that the prices grew 10% each year in comparison with 2012 prices.
#
# **Assignment:** Make a plot showing the real and nominal change of GDP starting with 2012 and up till 2022.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# Data Preparation

years = np.arange(2012, 2022, 1)
gdp = np.arange(100, 150, 5)
price_index = np.linspace(1, 2, 10)
real_gdp = gdp / price_index

# Plot Layout
fig = plt.figure(figsize=(14, 10))
fig.subplots_adjust(hspace=0.35)

gs = mpl.gridspec.GridSpec(2, 2)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[1,:])

# Plot Colors
grid_color = "#d0d3d4"
nominal_color = "#2980b9"
real_color = "#fc712b"


# Nominal GDP Plot
ax1.bar(years, gdp, color=nominal_color)
ax1.set_title("Nominal GDP, bln. EUR",  fontsize=16, pad=10)

# Axis Formatting
ax1.set_ylim(0, 160)
ax1.set_xticks(years)
ax1.spines["top"].set_color(grid_color)
ax1.spines["right"].set_color(grid_color)
ax1.set_xlabel("Year", fontsize=12, weight="bold")
ax1.set_ylabel("GDP (bln. EUR)", fontsize=12, weight="bold")

# Add Horizontal Grid
ax1.grid(axis='y', color=grid_color)

# Real GDP Plot
ax2.bar(years, real_gdp, color=real_color)
ax2.set_title("Real GDP, bln. EUR (in 2012 prices)", fontsize=16, pad=10)

# Axis Formatting
ax2.set_ylim(0, 160)
ax2.set_xticks(years)
ax2.spines["top"].set_color(grid_color)
ax2.spines["right"].set_color(grid_color)
ax2.set_xlabel("Year", fontsize=12, weight="bold")
ax2.set_ylabel("GDP (bln. EUR)", fontsize=12, weight="bold")

# Add Horizontal Grid
ax2.grid(axis='y', color=grid_color)


# Nominal GDP vs Real GDP
ax3.set_title("Nominal GDP vs Real GDP, bln. EUR", fontsize=16, pad=10)
ax3.plot(years, gdp, color=nominal_color, label="Nominal GDP")
ax3.plot(years, real_gdp, color=real_color, label="Real GDP")

# Axis Formatting
ax3.set_ylim(0, 160)
ax3.set_xticks(years)
ax3.spines["top"].set_color(grid_color)
ax3.spines["right"].set_color(grid_color)
ax3.set_xlabel("Year", fontsize=12, weight="bold")
ax3.set_ylabel("GDP (bln. EUR)", fontsize=12, weight="bold")

# Add Legend
ax3.legend()

# Add Grid
ax3.grid()

# Display Plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import numpy as np
#       2 import matplotlib.pyplot as plt
#       3 import matplotlib as mpl
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# ## 2. GDP Per Capita

# %% [markdown]
# **GDP per capita** is a measurement of the GDP per person in a country’s population. It indicates that the amount of output or income per person in an economy can indicate average productivity or average living standards. GDP per capita can be nominal or real, dependant on analysis goals.
#
# At a basic interpretation, per-capita GDP shows how much economic production value can be attributed to each individual citizen. This also translates to a measure of overall national wealth since GDP market value per person also readily serves as a prosperity measure.

# %% [markdown]
# ## Exercise 2: Comparing EU Countries GDP in 2021
#
# Per-capita GDP is often analyzed alongside more traditional measures of GDP. Economists use this metric for insight into their own country’s domestic productivity and the productivity of other countries. In this exercise
# we will compare GDP per capita of EU countries in 2022.
#
# When we compare performance of the countries in a given year it is OK to use nominal GDP.
#
# **Assignment 1:** Plot the 2022 GDP per capita for Estonia, Latvia, Lithuania, Finland, and Denmark. Use vertical bar chart to visualize the data.
#
# **Assignment 2:** Plot the 2022 GDP per capita for all 27 EU countries. Use horizontal bar chart to display the data. The visualization data is stored in the file **gdp_per_capita_2022.csv**.

# %% [markdown]
# ## Solution to Exercise 2, Assignment 1

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# Data preparation
gdp_data = {
    "Denmark":69845,
    "Estonia":46125,
    "Findland": 58569,
    "Latvia": 38123,
    "Lithuania":46158
}

countries = gdp_data.keys()
gdp = gdp_data.values()

fig, ax = plt.subplots(layout = "constrained")
bchart = ax.bar(countries, gdp)

ax.set_title("GDP per capita, 2022, EUR")

ax.bar_label(bchart, label_type = "edge", padding = 5)

ax.set_ylim(0, 80000),
ax.set_ylabel("GDP per Capita, EUR\n", fontsize = 12, fontweight = "bold")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import matplotlib.pyplot as plt
#       3 import matplotlib as mpl
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# ## Solution to Exercise 2, Assignment 2

# %%
import numpy as np
import pandas as pd

#Data preview
data = pd.read_csv("data/gdp_per_capita2022.csv")
display(data.head())

#accses column
type(data["GDP"])
Display(data["GDP"].head)

#Read data
data1 = pd.read_csv("data/gdp_per_capita2022.csv", index_col="country")
data1.head()

#Accses row
display(data1.iloc[0])
display(data1.iloc[0,:])
display(data1.loc["Luxemburg"])
display(data1.loc["Luxemburg",:])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#       4 #Data preview
#       5 data = pd.read_csv("data/gdp_per_capita2022.csv")
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as npl

#data preparation
data = pd_read_csv["data/gdp_per_capita_2022.csv"]
countries = data["country"]
gdps = data["GDP"]
hb_plt = np.array(data.index) 

#Plot
fig.ax = plt.subplots(figsize)

#
ax.set_

#
ax.set_

# %% [markdown]
# ## 3. GDP Growth Rate
#
# The **GDP growth rate** compares the year-over-year change in a country’s economic output to measure how fast an economy is growing. Usually expressed as a percentage rate, this measure is popular for economic policymakers because GDP growth is thought to be closely connected to key policy targets such as inflation and unemployment rates.
#
# In order to calculate the GDP growth rate the Real GDP is used, this is because we are comparing the performance over time.

# %% [markdown]
# ## Exercise 3: Comparing GDP Growth Rates

# %% [markdown]
# a) Compare Estonia, Latvia, and Lithuania GDP growth rates in 2017-2022. Use grouped bar chart to complete the exercise. Use the data from the file **bc_real_gdp_growth_rates.csv**.
#
# b) Compare Denmark, Finland, and Lithuania GDP growth rates in 2017-2022. Use grouped bar chart to complete the exercise. The growth rates data is located in **dfl_real_gdp_growth_rates.csv**.

# %% [markdown]
# ## Solution to Exercise 3(a):

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl


#Data preparation
data = pd.read_csv("data/bc_real_gdp_growth_rates.csv", index_col = "Country")
years = np.array(data.columns)
countries = np.array(data.index)

country_colors = {
    "Estonia", "#FF5733"
    "Latvia", "#FFF633"
    "Lithuania", "#49FF33"
}


fix, ax = plt.subplots(figsize = (8,4), layout = "constrained")

x_bar = np.arange(len(years))
width = 0.3
multyplier = 0

for country in countries:
    offset = width * multyplier
    country_gdp_rate = data.loc[country]
    cbar = ax.bar(x_bar+offset, country_gdp_rate, width, label= country)
    ax.bar_label(cbar, padding = 5)
    multyplier = multyplier +1

ax.set_title("GDP growth rated in Baltic States, 2017-2022, %")

ax.legend(loc = "upper left", ncols= len(countries))

ax.set_ylim(-4, 10)
ax.set_ylabel("GDP growth rate, %", fontsize = 12, fontweight = "bold" )

ax.set_xticks(x_bar +width, years)
ax.set_xlabel("GDP growth rate, %", fontsize = 12, fontweight = "bold" )

ax.axhline(y=0)

# %% [markdown]
# ## Solution to Exercise 3(b):

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

#Data preparation
data = pd.read_csv("data/dfl_real_gdp_growth_rates.csv", index_col = "Country")
years = np.array(data.columns)
countries = np.array(data.index)

country_colors = {
    "Denmark", "#4CFF33"
    "Finland", "#FF3333"
    "Lithuania", "#49FF33"
}

fix, ax = plt.subplots(figsize = (8,4), layout = "constrained")

x_bar = np.arange(len(years))
width = 0.3
multyplier = 0

for country in countries:
    offset = width * multyplier
    country_gdp_rate = data.loc[country]
    cbar = ax.bar(x_bar+offset, country_gdp_rate, width, label = country)
    ax.bar_label(cbar, padding = 5)
    multyplier = multyplier +1

ax.set_title("GDP growth rated in Denmark, Finland and Lithuania, 2017-2022, %")

ax.legend(loc = "upper left", ncols= len(countries))

ax.set_ylim(-4, 10)
ax.set_ylabel("GDP growth rate, %", fontsize = 12, fontweight = "bold" )

ax.set_xticks(x_bar +width, years)
ax.set_xlabel("GDP growth rate, %", fontsize = 12, fontweight = "bold" )

ax.axhline(y=0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl


#Data preparation
data = pd.read_csv("data/dfl_real_gdp_growth_rates.csv", index_col = "Country")
years = np.array(data.columns)
countries = np.array(data.index)

country_colors = {
    "Denmark": "#FF5733",
    "Finland": "#FFF633",
    "Lithuania": "#49FF33"
}


fix, ax = plt.subplots(figsize = (8,4), layout = "constrained")

x_bar = np.arange(len(years))
width = 0.3
multyplier = 0

for country in countries:
    offset = width * multyplier
    country_gdp_rate = data.loc[country]
    cbar = ax.bar(x_bar+offset, country_gdp_rate, width, label= country, color = country_colors[country])
    ax.bar_label(cbar, padding = 5)
    multyplier = multyplier +1

ax.set_title("GDP growth rated in Denmark, Finland and Lithuania, 2017-2022, %")

ax.legend(loc = "upper left", ncols= len(countries))

ax.set_ylim(-4, 10)
ax.set_ylabel("GDP growth rate, %", fontsize = 12, fontweight = "bold" )

ax.set_xticks(x_bar +width, years)
ax.set_xlabel("GDP growth rate, %", fontsize = 12, fontweight = "bold" )


ax.axhline(y=0)

# %% [markdown]
# ## 4. GDP Calculation

# %% [markdown]
# GDP can be calculated in three ways:
#
# 1) Expenditure approach
#
# 2) Production approach
#
# 3) Income approach

# %% [markdown]
# ## 4.1 Expenditure Approach

# %% [markdown]
# The expenditure appraoch relies on calculation of spendings of economy participants.
#
# $$ GDP = C + G + I + NX $$
#
# - C - Private consumption and spendings
# - G - Government spendings
# - I - Private domestic investments, business investments
# - NX - Net Export (NX = Exports - Imports)

# %% [markdown]
# ## Exercise 4.1: Lithuanian GDP Components  in 2017-2021

# %% [markdown]
# a) Make a stacked bar chart showing Lithuanina GDP expenditure components (Private consumption, government spendings, and investments).  Use 2017-2022 data.
#
# b) Make a separate bar chart plot for showing the net exports.
#
# Use the data from **lt_gdp_structure.csv**.

# %% [markdown]
# ## Solution to Exercise 4.1(a)

# %% [markdown]
# ## Exercise 4.2: GDP Expenditure Components  in 2017-2022

# %% [markdown]
# In the previous exercise we plotted Lithuanian GDP expenditure components. Now we want to compare the expenditure structure of Lithuanian GDP with Denmark and Finland.
#
# Your task is to plot Denamark and Finland GDP structure, and compare it with Lithuanian GDP structure.
# You need to explain what is similar and what is different when comparing Lithuanina GDP structure with Finland and Denmark GDPs.
#
# The data is contained in the following files: **private_consumption.csv**, **government_spendings.csv**
# , **investments.csv**, **net_exports.csv**. You are free to construct and use you own datasets, however be sure that you save the datasets you used together with the notebook.
#
# Hint: You already have GDP structure graph for Lithuania, and you need to plot the same graphs for Finland and Denmark.

# %% [markdown]
# ## Solution to Exercise 4.2
